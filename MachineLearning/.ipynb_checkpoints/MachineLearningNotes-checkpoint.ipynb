# %%
from IPython.display import display, Image

# %% [markdown]
# # Yapay Ogrenme

# %% [markdown]
# * Yapay ogrenme, deneyimlerle kendi kendini gelistiren bilgisayar algoritmalarini calisan alandir.
#
# * Cok buyuk miktardaki verilerin elle islenip analiz edilmesi mumkun degildir. Bu tur problemlere cozum bulmak amaciyla yapay ogrenme metotlari gelistirilmistir.
#
# * Bu metotlar gecmisteki verileri kullanarak veriye en uygun modeli bulmaya calisirlar. Yeni gelen verileri de bu modele gore analiz edip sonuc uretirler.
#
# * Farkli uygulamalarin analizlerden fakli beklentileri olmaktadir. Yapay ogrenme metotlarini bu beklentilere gore siniflandirmak mumkundur.

# %% [markdown]
# ### Yapay ogrenmeyi 3 baslikda inceleyecegiz:

# %%
display(Image(filename='images/3baslik.png'))

# %% [markdown]
# ## Danismanli Ogrenme
# Veri kumesinde girdilerden ciktilara ulasmak icin kullanilacak fonksiyonu bulmayi amaclar. Ornek olarak: Destek Vektor Makinalari, Sinir Aglari, Karar Agaclari, K-en yakin komsu algoritmasi, Naive Bayes vb. verilebilir.
#
# #### Siniflandirma:
# Birden fazla kategoriden ornekler gosterildiginde daha once gosterilmeyen bir seyin bu kategorilerden hangisine ait oldugunu soyleyebilmek demektir.

# %%
display(Image(filename='images/danismanli&siniflandirma.png'))

# %% [markdown]
# ## Siniflandirma

# %%
display(Image(filename='images/siniflandirma.png'))

# %% [markdown]
# ### Regresyon (Egri Uydurma):
# Girdiler ve ciktilar arasindaki iliskiyi tanimlayan fonsiyonu uretme ve girdilerin degisimine gore ciktilarin degisimini tahmin etme cabasidir.

# %%
display(Image(filename='images/danismanliRegresyon.png'))

# %% [markdown]
# ## Danismansiz Ogrenme (Unsupervised Learning)
# Verilerin girdi kumesi icindeki desenleri bulabilen algoritmalardir. Veriler etiketlenmemis durumdadir. Hangi nesnenin hangi sinifa ait oldugu ve grup sayisi belirsizdir. Ornek olarak: K-means, gaussian karisim modelleri (GMM), hiyerarsik kumeleme, spektral kumeleme vb. verilebilir.
#
# #### Kumeleme:

# %%
display(Image(filename='images/kumeleme.png'))

# %% [markdown]
# ## Egitim Ve Test

# %%
display(Image(filename='images/egitimVeTest.png'))
