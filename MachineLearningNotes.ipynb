# %%
from IPython.display import display, Image

# %% [markdown]
# # Yapay Ogrenme

# %% [markdown]
# * Yapay ogrenme, deneyimlerle kendi kendini gelistiren bilgisayar algoritmalarini calisan alandir.
#
# * Cok buyuk miktardaki verilerin elle islenip analiz edilmesi mumkun degildir. Bu tur problemlere cozum bulmak amaciyla yapay ogrenme metotlari gelistirilmistir.
#
# * Bu metotlar gecmisteki verileri kullanarak veriye en uygun modeli bulmaya calisirlar. Yeni gelen verileri de bu modele gore analiz edip sonuc uretirler.
#
# * Farkli uygulamalarin analizlerden fakli beklentileri olmaktadir. Yapay ogrenme metotlarini bu beklentilere gore siniflandirmak mumkundur.

# %% [markdown]
# ### Yapay ogrenmeyi 3 baslikda inceleyecegiz:

# %%
display(Image(filename='images/3baslik.png'))

# %% [markdown]
# ## Danismanli Ogrenme
# Veri kumesinde girdilerden ciktilara ulasmak icin kullanilacak fonksiyonu bulmayi amaclar. Ornek olarak: Destek Vektor Makinalari, Sinir Aglari, Karar Agaclari, K-en yakin komsu algoritmasi, Naive Bayes vb. verilebilir.
#
# #### Siniflandirma:
# Birden fazla kategoriden ornekler gosterildiginde daha once gosterilmeyen bir seyin bu kategorilerden hangisine ait oldugunu soyleyebilmek demektir.

# %%
display(Image(filename='images/danismanli&siniflandirma.png'))

# %% [markdown]
# ## Siniflandirma

# %%
display(Image(filename='images/siniflandirma.png'))

# %% [markdown]
# ### Regresyon (Egri Uydurma):
# Girdiler ve ciktilar arasindaki iliskiyi tanimlayan fonsiyonu uretme ve girdilerin degisimine gore ciktilarin degisimini tahmin etme cabasidir.

# %%
display(Image(filename='images/danismanliRegresyon.png'))

# %% [markdown]
# ## Danismansiz Ogrenme (Unsupervised Learning)
# Verilerin girdi kumesi icindeki desenleri bulabilen algoritmalardir. Veriler etiketlenmemis durumdadir. Hangi nesnenin hangi sinifa ait oldugu ve grup sayisi belirsizdir. Ornek olarak: K-means, gaussian karisim modelleri (GMM), hiyerarsik kumeleme, spektral kumeleme vb. verilebilir.
#
# #### Kumeleme:

# %%
display(Image(filename='images/kumeleme.png'))

# %% [markdown]
# ## Egitim Ve Test

# %%
display(Image(filename='images/egitimVeTest.png'))

# %% [markdown]
# ## Yapay Ogrenme'de Soru(n)lar
#
# * Bir kavrami ogrenmek icin hangi algoritmalar mevcuttur? Ne kadar iyi performans gosteriyorlar?
#
# * Bir kavrami yuksek guvenler ogrenmek icin ne kadar egitim verisi yeterlidir?
#
# * Bazi egitim ornekleri digerlerinden daha mi faydalidir?
#
# * Bir sistemin ogrenmesi icin en iyi gorevler nelerdir?
#
# * Bir sistemin bilgisini temsil etmesinin en iyi yolu nedir?

# %% [markdown]
# * Performans cok onemli performansi olcup en iyi olan algoritmayi kullanmamiz gerekiyor
# * Egitim verilerinin yuzdesi Akademik yayinlarda %70 ile %80 orani olmasi gerektigi soyleniyor

# %% [markdown]
# ## Bazi Ornekler ve Algoritmalar

# %%
display(Image(filename='images/ornek1Lineer.png'))

# %% [markdown]
# #### Yukaridaki problemi Lineer Regresyon ile cozebiliriz. Asamali Azaltma(Gradient descent) ile de optimize ederiz

# %%
display(Image(filename='images/ornek2Karar.png'))

# %% [markdown]
# #### Yukaridaki kullanicilara Karar Agaclari (Decision Tree) ile farkli uygulamalar onerebiliz.

# %%
display(Image(filename='images/ornek3Kmeans.png'))

# %% [markdown]
# #### Yukaridaki ornekte gazete dagitimi yapan kuryeye K-ortalamalar (K-means) kumeleme algoritmasi ile yardimci olabiliriz.

# %% [markdown]
# ## Karar Agaclari (Decision Trees)

# %%
display(Image(filename='images/ornek4Decison.png'))

# %% [markdown]
# Karar agaclarindaki en temel problem ilk bastaki kok dugumunun belirlenmesi. (salary at least $50,000)

# %%
display(Image(filename='images/ornek5Decison.png'))

# %%
display(Image(filename='images/cozum5Decison.png'))

# %% [markdown]
# ## Pekistirmeli (Reinforcement) Ogrenme
#
# * 'Dijital ikiz' teknolojilerinin yukselisiyle birlikte, isletmeler artik RL aracilarini dijital ikiz simulasyonu icinde en iyi sekilde hareket edecek sekilde egitme potansiyeline sahiptir.
#
# * Dinamik fiyatlandirmaya sahip bir pazar yerinin dijital ikizi (Ornegin, bir reklam platformu veya mallar icin spot pazar) verildiginde, kari en ust duzeye cikarmak icin satin alma ve satma icin en uygun zamanlari ve miktarlari tahmin etmek uzere RL kullanarak bir arac egitilebilmektedir.
#
# * Bekleme surelerini en aza indimek icin yatak sayilari ve personel ile ilgili parametreleri ayarlamak uzere bir araciyi egiterek bir hastanedeki hasta akisini yonetmek.

# %%
display(Image(filename='images/ReinforcementOrnek1.png'))
